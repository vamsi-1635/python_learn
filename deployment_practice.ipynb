# %% [markdown]
# # Deployment & Productivity Practice
# Use this notebook to learn deployment, version control, and environment setup concepts.

# %% [markdown]
# ## Question 1
# Write a Python string `git_steps` that lists the basic git commands for initializing a repository, adding files, committing, and pushing.

# %%
# Write your answer below

git_steps = """"""

print(git_steps)

# %% [markdown]
# ## Question 2
# Create a function `make_virtualenv(name)` that returns the shell command string for creating a virtual environment named `name`.

# %%
# Write your function below

def make_virtualenv(name):
    pass

# Test your solution
print(make_virtualenv('env'))

# %% [markdown]
# ## Question 3
# Write a function `deploy_instructions(platform)` that returns a short text summary for deploying a Flask app on the given platform.

# %%
# Write your function below

def deploy_instructions(platform):
    pass

# Test your solution
print(deploy_instructions('Heroku'))
