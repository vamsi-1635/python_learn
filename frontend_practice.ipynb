# %% [markdown]
# # Frontend Practice
# This notebook helps you learn HTML, CSS, and JavaScript structure. You can write code snippets in the cells and review them.

# %% [markdown]
# ## Question 1
# Write a simple HTML page structure as a Python string in the variable `html_page`.

# %%
# Write your HTML string below
html_page = """"""

print(html_page)

# %% [markdown]
# ## Question 2
# Create a simple CSS rule block in the variable `css_styles` that makes the body background light blue.

# %%
# Write your CSS string below
css_styles = """"""

print(css_styles)

# %% [markdown]
# ## Question 3
# Write a JavaScript snippet in `js_script` that logs `Hello from JS` to the console.

# %%
# Write your JavaScript string below
js_script = """"""

print(js_script)
