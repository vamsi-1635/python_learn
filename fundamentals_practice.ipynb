# %% [markdown]
# # Python Fundamentals Practice
# Use this notebook to solve beginner Python questions. For each question, write your answer in the code cell below and run it to validate your solution.

# %% [markdown]
# ## Question 1
# Write a function `reverse_string(s)` that returns the reversed string without using Python's built-in reversed methods.

# %%
# Write your function below

def reverse_string(s):
    pass

# Test your solution
print(reverse_string("python"))  # expected: nohtyp

# %% [markdown]
# ## Question 2
# Create a function `count_words(text)` that returns a dictionary with the count of each word in the given text.

# %%
# Write your function below

def count_words(text):
    pass

# Test your solution
sample = "Python is fun and Python is easy"
print(count_words(sample))

# %% [markdown]
# ## Question 3
# Write a function `save_notes(notes, filename)` that writes the list of note strings to a file, one note per line.

# %%
# Write your function below

def save_notes(notes, filename):
    pass

# Test your solution
notes = ["Learn variables", "Practice loops"]
save_notes(notes, "test_notes.txt")
