# %% [markdown]
# # Data & Automation Practice
# Solve data tasks using Python and prepare simple automation logic.

# %% [markdown]
# ## Question 1
# Create a function `create_dataframe()` that returns a pandas DataFrame from a dictionary.

# %%
import pandas as pd

# Write your function below

def create_dataframe():
    pass

# Test your solution
df = create_dataframe()
print(df)

# %% [markdown]
# ## Question 2
# Write a function `summarize_data(df)` that returns the average age from the DataFrame.

# %%
# Write your function below

def summarize_data(df):
    pass

# Test your solution
# Use the dataframe from the previous question

# %% [markdown]
# ## Question 3
# Write a function `parse_html_titles(html)` that finds all `<title>` tags inside a string and returns them.

# %%
# Write your function below

def parse_html_titles(html):
    pass

# Test your solution
html = "<html><head><title>Page</title></head></html>"
print(parse_html_titles(html))
