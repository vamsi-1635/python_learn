# %% [markdown]
# # Object-Oriented Programming Practice
# Write classes and methods in the code cells below. Run the tests after your implementation.

# %% [markdown]
# ## Question 1
# Create a `Student` class with `name`, `marks` list, and a method `average()` that returns the average mark.

# %%
# Write your class below

class Student:
    pass

# Test your solution
student = Student("Asha", [80, 90, 85])
print(student.average())  # expected: 85.0

# %% [markdown]
# ## Question 2
# Create a `Shape` base class and a `Rectangle` subclass that implements `area()`.

# %%
# Write your classes below

class Shape:
    pass

class Rectangle(Shape):
    pass

# Test your solution
rect = Rectangle(4, 5)
print(rect.area())  # expected: 20

# %% [markdown]
# ## Question 3
# Implement `__str__` for a `Book` class so that printing the object shows title and author.

# %%
# Write your class below

class Book:
    pass

# Test your solution
book = Book("Python Basics", "Vamsi")
print(book)  # expected: Python Basics by Vamsi
