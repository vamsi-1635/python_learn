# %% [markdown]
# # Python Practice Notes
#
# This notebook is your daily place to store: learning paths, practice plan, questions, notes, and doubts.
# Use it every day to track progress and write down ideas or problems you want to ask about.

# %% [markdown]
# ## Suggested Learning Paths
#
# 1. Python Fundamentals
# 2. Object-Oriented Programming
# 3. Web Development with Flask/Django
# 4. Frontend Basics (HTML, CSS, JS)
# 5. APIs and Full-Stack Integration
# 6. Data, Automation, and Deployment

# %% [markdown]
# ## 4-Week Practice Plan
#
# Week 1: Python Fundamentals
# - Day 1: variables, data types, and operations
# - Day 2: conditions and loops
# - Day 3: functions and return values
# - Day 4: lists, tuples, and sets
# - Day 5: dictionaries and nested structures
# - Day 6: file reading/writing
# - Day 7: small project - calculator or note logger
#
# Week 2: OOP and Modules
# - Day 1: classes and object creation
# - Day 2: methods, attributes, and constructors
# - Day 3: inheritance and composition
# - Day 4: special methods and dunder methods
# - Day 5: modules and package structure
# - Day 6: build a contact manager class project
# - Day 7: review and refactor code
#
# Week 3: Web Development Basics
# - Day 1: install Flask and build a hello world app
# - Day 2: routes, templates, and forms
# - Day 3: build a simple CRUD app
# - Day 4: learn JSON and API responses
# - Day 5: add frontend form handling
# - Day 6: deploy a simple app locally
# - Day 7: review and document the project
#
# Week 4: Frontend and Integration
# - Day 1: HTML structure and CSS basics
# - Day 2: JavaScript variables and functions
# - Day 3: DOM manipulation and events
# - Day 4: fetch API and AJAX requests
# - Day 5: connect frontend to the Flask backend
# - Day 6: build a small full-stack page
# - Day 7: review, test, and improve UI

# %% [markdown]
# ## Practice Questions
#
# 1. Reverse a string without using built-in reverse methods.
# 2. Count word frequency in a text file.
# 3. Create a number guessing game.
# 4. Write a student record class with average calculation.
# 5. Build a Flask app that accepts form input and displays the result.
# 6. Scrape headlines from a website with BeautifulSoup.
# 7. Read a CSV and summarize the data.
# 8. Make a REST API endpoint returning JSON.
# 9. Initialize Git, commit changes, and push to GitHub.
# 10. Create an HTML page that calls an API endpoint and shows data.
#
# ## Advanced Python Questions
#
# 1. Implement a decorator that logs function execution time.
# 2. Write a generator function to produce an infinite sequence of prime numbers.
# 3. Build a command-line tool that parses arguments and processes files.
# 4. Create a custom exception class and use it in a validation flow.
# 5. Write a threaded script that downloads files concurrently.
# 6. Develop a small Flask app with user authentication.
# 7. Create a data analysis script using pandas and visualize results with Matplotlib.
# 8. Build a REST API client that consumes an external JSON API and displays results.
# 9. Write unit tests for a set of functions using pytest or unittest.
# 10. Refactor an existing script to use classes, modules, and better structure.
#
# ## Beginner Project Tracker
#
# - Daily Python Tracker
#   - Track daily learning and save notes every day.
#   - Milestones: create the tracker, log 7 days, review the week.
# - Calculator App
#   - Build a console calculator with validation.
#   - Milestones: implement operations, add error handling, refactor.
# - Contact Manager
#   - Create contact add/update/delete features.
#   - Milestones: store contacts, add search, save/load from file.
#
# ## Weekly Checklist
#
# - Week 1: Review Python basics, solve one problem, write a short summary, commit code.
# - Week 2: Practice OOP, build or refactor a small module, add tests, improve readability.
# - Week 3: Create a Flask app, use routing and templates, add JSON output, document your work.
# - Week 4: Learn HTML/CSS/JS, connect frontend with backend, build a small full-stack page, deploy or share your project.
#
# ## Small Web App Learning Path
#
# 1. Choose a simple idea: todo app, notes app, or budget tracker.
# 2. Build backend routes with Flask and return HTML or JSON.
# 3. Create a frontend page with HTML and CSS.
# 4. Use JavaScript fetch() to call your backend API.
# 5. Add data persistence using files or a database.
# 6. Test the app, fix bugs, and document the project.

# %% [markdown]
# ## Daily Itinerary
#
# - Week 1: `fundamentals_practice.ipynb` each day for Python basics.
# - Week 2: `oop_practice.ipynb` each day for classes, inheritance, and methods.
# - Week 3: `web_development_practice.ipynb` plus `frontend_practice.ipynb` for Flask and UI.
# - Week 4: `data_automation_practice.ipynb` for pandas and automation, then review all notebooks.
#
# Use this notebook to track progress, then open the named notebook for the day’s topic.

# %% [markdown]
# ## Daily Notes
#
# Write your progress here every day:
# - What you learned
# - What was hard
# - What questions you have
# - Ideas for next practice

# %%
from python_practice_plan import show_paths, show_plan, show_questions, show_itinerary

show_paths()
show_plan()
show_questions()
show_itinerary()
