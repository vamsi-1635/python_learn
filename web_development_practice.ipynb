# %% [markdown]
# # Web Development Practice
# Use this notebook to learn Flask basics and API design. The code cells include validation where possible.

# %% [markdown]
# ## Question 1
# Write a simple Flask route function `hello()` that returns the string `"Hello, World!"`.

# %%
# Write your function below

def hello():
    pass

# Test your solution
print(hello())

# %% [markdown]
# ## Question 2
# Create a function `get_user_data()` that returns JSON-like dictionary data for a user.

# %%
# Write your function below

def get_user_data():
    pass

# Test your solution
print(get_user_data())

# %% [markdown]
# ## Question 3
# Write a function `submit_form(name, email)` that returns a confirmation message.

# %%
# Write your function below

def submit_form(name, email):
    pass

# Test your solution
print(submit_form("Vamsi", "vamsi@example.com"))
